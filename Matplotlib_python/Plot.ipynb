# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("schools_with_computer.csv")

# %%
data.head()
# Out:
#                     State_UT     year  ...  HrSec_Only  All Schools
# 0  Andaman & Nicobar Islands  2013-14  ...        0.00        53.06
# 1  Andaman & Nicobar Islands  2014-15  ...        0.00        57.25
# 2  Andaman & Nicobar Islands  2015-16  ...        0.00        57.00
# 3             Andhra Pradesh  2013-14  ...       19.32        29.57
# 4             Andhra Pradesh  2014-15  ...       41.60        28.06
#
# [5 rows x 13 columns]

# %%
year_2013_14 = list(data.iloc[0,2:])
year_2014_15 = list(data.iloc[1,2:])
year_2015_16 = list(data.iloc[2,2:])

# %%
label = []
for col in data.columns:
    label.append(col)

# %% [markdown]
# ## Stacked Bar Plot

# %%
import matplotlib.pyplot as plt

labels = label[2:]
year_2013_14 = list(data.iloc[0,2:])
year_2014_15 = list(data.iloc[1,2:])
year_2015_16 = list(data.iloc[2,2:])
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(10,10))

ax.bar(labels, year_2013_14, width, label='year_2013_14')
ax.bar(labels, year_2014_15, width, bottom=year_2013_14,
       label='year_2014_15')
ax.bar(labels, year_2015_16, width, bottom=np.array(year_2013_14)+np.array(year_2014_15), label='year_2015_16')
plt.xticks(color='black', rotation=45, fontsize='12', horizontalalignment='right')
ax.set_ylabel('Percentage',fontsize='17')
ax.set_title('Percentage of Schools with Computers from 2013-14 to 2015-16 \n For Andaman and Nikobar State',fontsize='17')
ax.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
np.random.seed(19680801)

fig, ax = plt.subplots(figsize=(10,10))
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area1 = year_2013_14
area2 = year_2014_15
area3 = year_2015_16
ax.scatter(labels,year_2013_14,s=3*np.array(area1),label='year_2015_16')
ax.scatter(labels,year_2014_15,s=3*np.array(area2),label='year_2015_16')
ax.scatter(labels,year_2015_16,s=3*np.array(area3),label='year_2015_16')
plt.xticks(color='black', rotation=45, fontsize='12', horizontalalignment='right')
ax.set_ylabel('Percentage',fontsize='17')
ax.set_title('Percentage of Schools with Computers from 2013-14 to 2015-16 \n For Andaman and Nikobar State',fontsize='17')
ax.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Comment:
#
# *   Above is the scatter plot in which is point is represented by different circle with different colour and different radius which represent different category and magnitude propotional to radius of circle respectively

# %% [markdown]
# ## box plot

# %%
data_1 = year_2013_14
data_2 = year_2014_15
data_3 = year_2015_16
data = [data_1, data_2, data_3]
 
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(data,patch_artist = True,
                notch ='True')
ax.set_xticklabels(['year_2013_14', 'year_2014_15',
                    'year_2015_16'])
colors = ['#0000FF', '#00FF00',
          '#FFFF00']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)
plt.xticks(color='black', rotation=45, fontsize='12', horizontalalignment='right')
ax.set_ylabel('Percentage',fontsize='17')
ax.set_title('Percentage of Schools with Computers from 2013-14 to 2015-16 \n For Andaman and Nikobar State',fontsize='17')
plt.grid() 
# show plot
plt.show()
